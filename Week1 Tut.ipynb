# %%
print("Welcome to Data Engineering Module!")
# Out:
# Welcome to Data Engineering Module!

# %%
age = 25
pi = 3.14
name = "Sumaiya"
is_student = True
print(age,pi,name,is_student)
# Out:
# 25 3.14 Sumaiya True

# %%
print(f"Welcome to Data Engineering Module, my name is {name}, I am a student, and I am 22 years old.")
# Out:
# Welcome to Data Engineering Module, my name is Sumaiya, I am a student, and I am 22 years old.

# %%
a = 10
b = 3
print (a + b, a ** b,a // b)
# Out:
# 13 1000 3

# %%
#working with strings
text = "Data Engineering"
print(text.lower())
print(text[0:4]) # first word
print(text[::-1]) # reverse string through slicing
# Out:
# data engineering
# Data
# gnireenignE ataD

# %%
#Logical Opeartors
#and :Returns True if both statements are true
x = 10
print(f"x > 5 and x< 15: {x >5 and x< 15}")

#or: Returns True if one of the statements is true
y = 20
print(f"y > 10 or y < 25: {y > 10 or y < 25}")

#not: Reverse the result, returns False if the result is true
z = True
print(f"not z: {not z}")
# Out:
# x > 5 and x< 15: True
# y > 10 or y < 25: True
# not z: False

# %%
#Lists
fruits = ["apple", "banana", "cherry"]
print(fruits)
print(fruits[0]) # indexing
fruits.append("date") # add new item
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']
# apple
# ['apple', 'banana', 'cherry', 'date']

# %%
# Tuples (immutable sequences)
coordinates = (10.5, 20.3)
print(coordinates)
# Out:
# (10.5, 20.3)

# %%
# Dictionaries (key-value pairs)
student = {"name": "Alice", "age": 25, "course": "Data Engineering"}
print(student["name"])
print(student.get("course"))
# Out:
# Alice
# Data Engineering

# %%
# Sets (unique, unordered collection)
unique_numbers = {1, 2, 2, 3, 4}
print(unique_numbers)
# Out:
# {1, 2, 3, 4}

# %%
s = 'Hello, world.'
str(s)
str(1/7)
# Out:
# '0.14285714285714285'

# %%
#concatenating
x = 10 * 3.25
y = 200 * 200
s = 'The value of x is ' + str(x) + ', and y is ' + str(y) + '...'
print(s)
# Out:
# The value of x is 32.5, and y is 40000...

# %%
import pandas as pd
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
import sys
print(sys.version)
# Out:
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
